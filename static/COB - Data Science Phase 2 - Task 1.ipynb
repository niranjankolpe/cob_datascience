# %% [markdown]
# # CodesOnBytes
# ## Data Science Internship
# ### Phase 2

# %% [markdown]
# #### Task 1: Analyze the dataset and create graphs using seaborn and matplotlib.
#
# Dataset: https://docs.google.com/spreadsheets/d/e/2PACX-1vTSS-TcErkXNk8KB0AlijhitwetxeHD2M3R0HJl2QPMAyFq0fxFX4PFKnzAWLDnratIz67DNL6GsZnV/pub?output=csv

# %%
# Importing required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# Creating a Data Frame from the CSV file
df = pd.read_csv("original_netflix_dataset.csv")
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# 0     United States   9/25/2021          2020  PG-13     90 min
# 1            France   9/24/2021          2021  TV-MA   1 Season
# 2     United States   9/24/2021          2021  TV-MA   1 Season
# 3            Brazil   9/22/2021          2021  TV-PG     91 min
# 4     United States   9/24/2021          1993  TV-MA    125 min
# ...             ...         ...           ...    ...        ...
# 8785         Turkey   1/17/2017          2016  TV-PG  2 Seasons
# 8786  United States   9/13/2018          2016  TV-Y7  3 Seasons
# 8787       Pakistan  12/15/2016          2012  TV-PG   1 Season
# 8788       Pakistan   6/23/2018          2016   TV-Y   1 Season
# 8789       Pakistan    6/7/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 0                                         Documentaries
# 1     Crime TV Shows, International TV Shows, TV Act...
# 2                    TV Dramas, TV Horror, TV Mysteries
# 3                    Children & Family Movies, Comedies
# 4      Dramas, Independent Movies, International Movies
# ...                                                 ...
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# 8788                                           Kids' TV
# 8789                                           Kids' TV
#
# [8790 rows x 10 columns]

# %%
for i in range(len(df)):
    df["show_id"][i] = df["show_id"][i].split("s")[1]

# %%
df
# Out:
#      show_id     type                             title         director  \
# 0          1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1          3  TV Show                         Ganglands  Julien Leclercq
# 2          6  TV Show                     Midnight Mass    Mike Flanagan
# 3         14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4          8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785    8797  TV Show                        Yunus Emre        Not Given
# 8786    8798  TV Show                         Zak Storm        Not Given
# 8787    8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788    8784  TV Show                              Yoko        Not Given
# 8789    8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# 0     United States   9/25/2021          2020  PG-13     90 min
# 1            France   9/24/2021          2021  TV-MA   1 Season
# 2     United States   9/24/2021          2021  TV-MA   1 Season
# 3            Brazil   9/22/2021          2021  TV-PG     91 min
# 4     United States   9/24/2021          1993  TV-MA    125 min
# ...             ...         ...           ...    ...        ...
# 8785         Turkey   1/17/2017          2016  TV-PG  2 Seasons
# 8786  United States   9/13/2018          2016  TV-Y7  3 Seasons
# 8787       Pakistan  12/15/2016          2012  TV-PG   1 Season
# 8788       Pakistan   6/23/2018          2016   TV-Y   1 Season
# 8789       Pakistan    6/7/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 0                                         Documentaries
# 1     Crime TV Shows, International TV Shows, TV Act...
# 2                    TV Dramas, TV Horror, TV Mysteries
# 3                    Children & Family Movies, Comedies
# 4      Dramas, Independent Movies, International Movies
# ...                                                 ...
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# 8788                                           Kids' TV
# 8789                                           Kids' TV
#
# [8790 rows x 10 columns]

# %%
for i in range(len(df)):
    if df["type"].iloc[i] == "Movie":
        df["duration"].iloc[i] = df["duration"].iloc[i].replace("min", "")
    elif df["type"].iloc[i] == "TV Show":
        if "Seasons" in df["duration"].iloc[i]:
            df["duration"].iloc[i] = df["duration"].iloc[i].replace("Seasons", "")
        elif "Season" in df["duration"].iloc[i]:
            df["duration"].iloc[i] = df["duration"].iloc[i].replace("Season", "")

# %%
df
# Out:
#      show_id     type                             title         director  \
# 0          1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1          3  TV Show                         Ganglands  Julien Leclercq
# 2          6  TV Show                     Midnight Mass    Mike Flanagan
# 3         14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4          8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785    8797  TV Show                        Yunus Emre        Not Given
# 8786    8798  TV Show                         Zak Storm        Not Given
# 8787    8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788    8784  TV Show                              Yoko        Not Given
# 8789    8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating duration  \
# 0     United States   9/25/2021          2020  PG-13      90
# 1            France   9/24/2021          2021  TV-MA       1
# 2     United States   9/24/2021          2021  TV-MA       1
# 3            Brazil   9/22/2021          2021  TV-PG      91
# 4     United States   9/24/2021          1993  TV-MA     125
# ...             ...         ...           ...    ...      ...
# 8785         Turkey   1/17/2017          2016  TV-PG       2
# 8786  United States   9/13/2018          2016  TV-Y7       3
# 8787       Pakistan  12/15/2016          2012  TV-PG       1
# 8788       Pakistan   6/23/2018          2016   TV-Y       1
# 8789       Pakistan    6/7/2018          2016  TV-Y7       1
#
#                                               listed_in
# 0                                         Documentaries
# 1     Crime TV Shows, International TV Shows, TV Act...
# 2                    TV Dramas, TV Horror, TV Mysteries
# 3                    Children & Family Movies, Comedies
# 4      Dramas, Independent Movies, International Movies
# ...                                                 ...
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# 8788                                           Kids' TV
# 8789                                           Kids' TV
#
# [8790 rows x 10 columns]

# %%
df["show_id"] = df["show_id"].astype(int)
df["duration"] = df["duration"].astype(int)

# %%
df.dtypes
# Out:
# show_id          int32
# type            object
# title           object
# director        object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration         int32
# listed_in       object
# dtype: object

# %%
df
# Out:
#       show_id     type                             title         director  \
# 0           1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1           3  TV Show                         Ganglands  Julien Leclercq
# 2           6  TV Show                     Midnight Mass    Mike Flanagan
# 3          14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4           8    Movie                           Sankofa     Haile Gerima
# ...       ...      ...                               ...              ...
# 8785     8797  TV Show                        Yunus Emre        Not Given
# 8786     8798  TV Show                         Zak Storm        Not Given
# 8787     8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788     8784  TV Show                              Yoko        Not Given
# 8789     8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating  duration  \
# 0     United States   9/25/2021          2020  PG-13        90
# 1            France   9/24/2021          2021  TV-MA         1
# 2     United States   9/24/2021          2021  TV-MA         1
# 3            Brazil   9/22/2021          2021  TV-PG        91
# 4     United States   9/24/2021          1993  TV-MA       125
# ...             ...         ...           ...    ...       ...
# 8785         Turkey   1/17/2017          2016  TV-PG         2
# 8786  United States   9/13/2018          2016  TV-Y7         3
# 8787       Pakistan  12/15/2016          2012  TV-PG         1
# 8788       Pakistan   6/23/2018          2016   TV-Y         1
# 8789       Pakistan    6/7/2018          2016  TV-Y7         1
#
#                                               listed_in
# 0                                         Documentaries
# 1     Crime TV Shows, International TV Shows, TV Act...
# 2                    TV Dramas, TV Horror, TV Mysteries
# 3                    Children & Family Movies, Comedies
# 4      Dramas, Independent Movies, International Movies
# ...                                                 ...
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# 8788                                           Kids' TV
# 8789                                           Kids' TV
#
# [8790 rows x 10 columns]

# %%
# Analyzing the dataset for any null values
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
# Analyzing the dataset if any duplicate records are present
df.duplicated().value_counts()
# Out:
# False    8790
# Name: count, dtype: int64

# %%
sns.boxplot(df["release_year"])
plt.ylabel("Release Year")
plt.title("Boxplot for Release Year")
plt.show()
# Outliers are present in release_year attribute

# %%
# Removing the outliers
df = df[df["release_year"] > 2008]

# Displaying the boxplot
sns.boxplot(df["release_year"])
plt.ylabel("Release Year")
plt.title("Boxplot for Release Year")
plt.show()

# %%
df
# Out:
#       show_id     type                             title         director  \
# 0           1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1           3  TV Show                         Ganglands  Julien Leclercq
# 2           6  TV Show                     Midnight Mass    Mike Flanagan
# 3          14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 5           9  TV Show     The Great British Baking Show  Andy Devonshire
# ...       ...      ...                               ...              ...
# 8785     8797  TV Show                        Yunus Emre        Not Given
# 8786     8798  TV Show                         Zak Storm        Not Given
# 8787     8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788     8784  TV Show                              Yoko        Not Given
# 8789     8786  TV Show                               YOM        Not Given
#
#              country  date_added  release_year rating  duration  \
# 0      United States   9/25/2021          2020  PG-13        90
# 1             France   9/24/2021          2021  TV-MA         1
# 2      United States   9/24/2021          2021  TV-MA         1
# 3             Brazil   9/22/2021          2021  TV-PG        91
# 5     United Kingdom   9/24/2021          2021  TV-14         9
# ...              ...         ...           ...    ...       ...
# 8785          Turkey   1/17/2017          2016  TV-PG         2
# 8786   United States   9/13/2018          2016  TV-Y7         3
# 8787        Pakistan  12/15/2016          2012  TV-PG         1
# 8788        Pakistan   6/23/2018          2016   TV-Y         1
# 8789        Pakistan    6/7/2018          2016  TV-Y7         1
#
#                                               listed_in
# 0                                         Documentaries
# 1     Crime TV Shows, International TV Shows, TV Act...
# 2                    TV Dramas, TV Horror, TV Mysteries
# 3                    Children & Family Movies, Comedies
# 5                          British TV Shows, Reality TV
# ...                                                 ...
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# 8788                                           Kids' TV
# 8789                                           Kids' TV
#
# [7610 rows x 10 columns]

# %%
# Saving the dataframe as a CSV file
df.to_csv("phase2_task1_cleaned_dataset.csv")

# %%
# Getting a pair-plot
sns.pairplot(df)
plt.show()

# %%
# Insight No 1: USA has the highest number of movies and series content combined. Followed by India and United Kingdom
plt.figure(figsize=(15, 10))
sns.barplot(x=list(df["country"].value_counts().keys())[:10], y=list(df["country"].value_counts().values[:10]))
plt.grid()
plt.xlabel("Country")
plt.ylabel("Count of Movies and Series Combined")
plt.title("Country Vs Count (Movies and Series)")
plt.savefig("insight_1.png")
plt.show()

# %%
# Insight No 2: Rapid growth in content release has been observed from 2015 with peak in 2018 and decline thereof.
sns.barplot(x=list(df["release_year"].value_counts().keys()),
            y=list(df["release_year"].value_counts().values))
plt.savefig("insight_2.png")
plt.show()

# %%
# Insight No 3: Total 5091 Movies and 2519 Series have been created between the year 2009 and 2021
df["type"].value_counts().plot(kind="bar")
plt.grid()
plt.ylabel("Count")
plt.savefig("insight_3.png")
plt.show()

# %%
# Insight No 4: Most customers are adults since the content rated "TV-MA" tops the list of most popular content based on rating
df["rating"].value_counts().plot(kind="bar")
plt.grid()
plt.savefig("insight_4.png")
plt.show()

# %%
# Insight No 5:
# 1) Rajiv Chilaka has directed the most Movies and Alastair Fothergill has directed the most TV Shows
# 2) Most directors prefer to direct Movies rather than TV Shows
plt.figure(figsize=(10, 10))
plt.grid()
sns.countplot(data=df, x="director", hue="type",order=df.director.value_counts().iloc[1:11].index, palette=["Black", "Red"])
plt.xticks(rotation=20)
plt.savefig("insight_5.png")
plt.show()

# %%
df
# Out:
#       show_id     type                             title         director  \
# 0           1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1           3  TV Show                         Ganglands  Julien Leclercq
# 2           6  TV Show                     Midnight Mass    Mike Flanagan
# 3          14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 5           9  TV Show     The Great British Baking Show  Andy Devonshire
# ...       ...      ...                               ...              ...
# 8785     8797  TV Show                        Yunus Emre        Not Given
# 8786     8798  TV Show                         Zak Storm        Not Given
# 8787     8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788     8784  TV Show                              Yoko        Not Given
# 8789     8786  TV Show                               YOM        Not Given
#
#              country  date_added  release_year rating  duration  \
# 0      United States   9/25/2021          2020  PG-13        90
# 1             France   9/24/2021          2021  TV-MA         1
# 2      United States   9/24/2021          2021  TV-MA         1
# 3             Brazil   9/22/2021          2021  TV-PG        91
# 5     United Kingdom   9/24/2021          2021  TV-14         9
# ...              ...         ...           ...    ...       ...
# 8785          Turkey   1/17/2017          2016  TV-PG         2
# 8786   United States   9/13/2018          2016  TV-Y7         3
# 8787        Pakistan  12/15/2016          2012  TV-PG         1
# 8788        Pakistan   6/23/2018          2016   TV-Y         1
# 8789        Pakistan    6/7/2018          2016  TV-Y7         1
#
#                                               listed_in
# 0                                         Documentaries
# 1     Crime TV Shows, International TV Shows, TV Act...
# 2                    TV Dramas, TV Horror, TV Mysteries
# 3                    Children & Family Movies, Comedies
# 5                          British TV Shows, Reality TV
# ...                                                 ...
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# 8788                                           Kids' TV
# 8789                                           Kids' TV
#
# [7610 rows x 10 columns]

# %%
# Insight No 6: The most popular Genre is "International Movies" followed by "Dramas" and "International TV Shows"
genres = df.listed_in.str.split(", ").explode()
plt.figure(figsize=(10, 10))
genres.value_counts()[:10].plot(kind="bar",
                                color=["red", "green", "blue", "orange", "yellow", "cyan", "brown", "pink", "purple", "maroon"])
plt.xticks(rotation=35)
plt.savefig("insight_6.png")
plt.show()
